# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# The GET Method:
#
#
# GET is used to request data from a specified resource.
#
# The query is sent in the URL of a GET request.
#
# ex :
#
# When we search something in google it is sent to the url and visible in the url.
#
#
#
# GET requests can be cached
#
# GET requests remain in the browser history
#
# GET requests can be bookmarked
#
# GET requests should never be used when dealing with sensitive data
#
# GET requests have length restrictions
#
# GET requests are only used to request data (not modify)
#
#
#
# The POST Method:
#
# POST is used to send data to a server to create/update a resource.
#
# The data sent to the server with POST is stored in the body.
#
# ex:
#
# The emailid and password for gmail login is sent to the body and is not visible outside
#
#
# POST requests are never cached
#
# POST requests do not remain in the browser history
#
# POST requests cannot be bookmarked
#
# POST requests have no restrictions on data length

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
#  The Request, in Flask, is an object that contains all the data sent from the Client to Server.
#
#  This data can be recovered using the GET/POST Methods.
#
#  Simply we can say that get and post method is used with the help of request.
#
#  It helps in interacting with the web services.
#
#  It is used to send query over the web in flask.
#
#
#  ex:
#
#
# @app.route('/display', methods=['GET', 'POST'])
# def show():
#     if request.method == 'POST':
#         result = request.form
#
#
#         return render_template("result_data.html", result=result)

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Flask redirect is defined as a function or utility in Flask which allows developers to redirect users to a specified URL.

# %% [markdown]
# ![download.jpg](attachment:8a113d7e-7c07-49a8-958e-d372e518098f.jpg)

# %% [markdown]
# https://brown-psychiatrist-sbwzu.pwskills.app:5500/prod/msg redirects to https://brown-psychiatrist-sbwzu.pwskills.app:5500/msg
#
# The prod function redirects the user to the respective URL mentioned in the route.
#
# With the help of url_for it is able to link to the function.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates are files that contain static data as well as placeholders for dynamic data.
#
# A template is a file that can contain both fixed and dynamic content.
#
# A template is rendered with specific data to produce a final document.
#
# Flask uses the Jinja template library to render templates

# %% [markdown]
# Flask provides us the render_template() function which can be used to render the external HTML file to be returned as the response from the view function.

# %% [markdown]
# app.py
#
#
#
# from flask import *
#
# app = Flask(__name__)
#
# @app.route('/')
#
# def message():
#
#       return render_template('message.html')
#
# if __name__ == '__main__':
#
#    app.run(debug = True)
#
#
#
#
# here message.html is rendered with the help of render_template

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![1.JPG](attachment:05896e0f-09e9-41a7-9b10-4c3b6252e632.JPG)

# %% [markdown]
# ![2.JPG](attachment:43a108d2-4f41-49ec-bdbd-35e7f51c93ac.JPG)

# %% [markdown]
# ![3.JPG](attachment:fb28059f-cdfb-4fb2-a72c-f6781dc8927e.JPG)

# %% [markdown]
# ![4.JPG](attachment:fc09ce6a-d626-4287-8cc0-9bcb8b0dd606.JPG)

# %% [markdown]
# ![5.JPG](attachment:24de28c5-1677-4b83-a0fc-b2a088b69434.JPG)
